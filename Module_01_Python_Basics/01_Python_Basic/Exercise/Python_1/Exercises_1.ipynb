# %% [markdown]
# # Practice Exercises
#
# Rules:
# - Read the task
# - Write code in the cell below it
# - Run and compare with the **Expected Output**
# - Keep output **exactly** the same (spaces, lines, punctuation)
#
# ---
#
# ## Exercise 1 — Hello in one line
# **Task:** Print this exactly:
#
# **Expected Output:**
# ```
# Hello, Python!
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 — Print on 3 lines
# **Task:** Print each word on a new line.
#
# Words: `Data`, `Science`, `Rocks`
#
# **Expected Output:**
# ```
# Data
# Science
# Rocks
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 — Quotes inside output
# **Task:** Print this exactly:
#
# **Expected Output:**
# ```
# He said, "Learning Python is fun!"
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 4 — Use `\t` (tabs)
# **Task:** Print a mini table (use tabs).
#
# **Expected Output:**
# ```
# Name	Age	City
# Anand	24	Ahmedabad
# ```
#
# *(It should look like columns when printed.)*

# %%
# Your code here

# %% [markdown]
# ## Exercise 5 — Use `sep`
# **Task:** Print the numbers with a dash between them.
#
# Numbers: 1, 2, 3, 4, 5
#
# **Expected Output:**
# ```
# 1-2-3-4-5
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 6 — Date format with `sep`
# **Task:** Print the date as `30/01/2026`.
#
# Given:
# ```python
# day = 30
# month = 1
# year = 2026
# ```
#
# **Expected Output:**
# ```
# 30/1/2026
# ```

# %%
day = 30
month = 1
year = 2026

# Your code here

# %% [markdown]
# ## Exercise 7 — Use `end` to keep same line
# **Task:** Print `Loading...done!` using **two** print statements.
#
# **Expected Output:**
# ```
# Loading...done!
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 8 — Backslash printing
# **Task:** Print this path exactly:
#
# **Expected Output:**
# ```
# C:\Users\Lenovo\Documents
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 9 — Mix text + variables
# Given:
# ```python
# name = "Your_name"
# role = "Developer"
# ```
#
# **Task:** Print:
# `Anand is a Developer`
#
# **Expected Output:**
# ```
# Anand is a Developer
# ```

# %%
name = "Anand"
role = "Developer"

# Your code here

# %% [markdown]
# ## Exercise 10 — Print a simple receipt
# Given:
# ```python
# item = "Notebook"
# price = 49
# qty = 2
# ```
#
# **Task:** Print this exactly (line breaks matter):
#
# **Expected Output:**
# ```
# Item: Notebook
# Price: 49
# Qty: 2
# Total: 98
# ```

# %%
item = "Notebook"
price = 49
qty = 2

# Your code here

# %% [markdown]
# ## Exercise 11 — Custom separator and ending
# **Task:** Print the words with ` | ` between them and end with ` ✅`.
#
# Words: `learn`, `build`, `ship`
#
# **Expected Output:**
# ```
# learn | build | ship ✅
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 12 — Clean spacing challenge (exact formatting)
# **Task:** Print this exactly (notice blank line):
#
# **Expected Output:**
# ```
# START
#
# END
# ```

# %%
# Your code here
